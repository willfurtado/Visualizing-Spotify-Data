# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

plt.style.use('default')

NUM_CLUSTERS = 7

# %%
df = pd.read_csv("features/features.csv", index_col=0)

# %% [markdown]
# ## Function Schema

# %% [markdown]
# Within the Notebook, we have the following functions to assist our feature engineering and clustering:
#
# >1. `clean_raw_df`: Returns a clean version of the raw DataFrame.
# 2. `one_hot`: One hot encodes the Mode and Time Signature features.
# 3. `center`: Centers the data of a DataFrame by subtracting the mean row.
# 4. `design_matrix`: Returns a design matrix (NumPy) for future work.
# 5. `plot_scree`: Given a SVD of a matrix, plots the scree plot.
# 6. `cluster_data`: Performs k-Means clustering on the given data.
# 7. `plot_pca`: Plots the dimensionality-reduced data using first two principal components.
# 8. `pipeline`: Performs the whole process.
# >

# %%
def clean_raw_df(df: pd.DataFrame, pipe=True) -> pd.DataFrame:
    """Returns a clean version of the raw DataFrame"""
    df = df.drop_duplicates(subset=["uri"]).set_index("uri").dropna()
    df = df[~df['title'].str.contains("rain", case=False)]
    if pipe:
        df = df.drop(["track_href", "id", "title", "type", "analysis_url"], axis=1)
    df = df[df['time_signature'] > 0.0]
    df = df.replace({"mode": {1.0:"major", 0.0: "minor"}})

    return df

# %%
def one_hot(df: pd.DataFrame) -> pd.DataFrame:
    """One hot encodes the Mode and Time Signature Features"""
    oh_enc = OneHotEncoder()
    oh_enc.fit(df[['mode', "time_signature", "key"]])
    dummies = pd.DataFrame(oh_enc.transform(df[['mode', "time_signature", "key"]]).todense(), 
                           columns=oh_enc.get_feature_names(['mode', "time_signature", "key"]),
                           index = df.index)
    return df.join(dummies).drop(['mode', "time_signature", "key"], axis=1)

# %%
def center(df: pd.DataFrame) -> pd.DataFrame:
    """ Returns a design matrix for PCA from a given DataFrame"""
    means = np.mean(df)
    centered = df - means
    
    return centered

# %%
def design_matrix(df: pd.DataFrame) -> pd.DataFrame:
    """Returns the design matric of the DataFrame"""
    return StandardScaler().fit_transform(df.to_numpy())

# %%
def plot_scree(df: pd.DataFrame) -> None:
    """Creates a scree plot of the singular values of the SVD"""
    u, s, vt = np.linalg.svd(design_matrix(df), full_matrices=False)
    num_features = s.shape[0] + 1
    
    plt.figure(figsize=(10,5))
    plt.plot(list(range(1,num_features)), s**2 / sum(s**2))
    plt.xticks(list(range(1, num_features)), list(range(1,num_features)))
    plt.xlabel('PC #');
    plt.ylabel('Fraction of Variance Explained');
    plt.title('Fraction of Variance Explained by each Principal Component');

# %%
def cluster_data(df: pd.DataFrame, clusters=NUM_CLUSTERS) -> tuple:
    """Performs the KMeans Clustering of the data"""
    X = design_matrix(df)
    pca = PCA(n_components=2)
    principal_components = pca.fit_transform(X)

    target_df_pca = pd.DataFrame(data=principal_components, columns=['PC_1', 'PC_2'])

    kmeans_pca = KMeans(n_clusters=clusters, init='k-means++', n_init=25)
    predicted_pca = kmeans_pca.fit_predict(principal_components)
    
    target_df_pca['prediction'] = predicted_pca
    target_df_pca.set_index(keys=df.index, inplace=True)
    
    return target_df_pca, kmeans_pca

# %%
def plot_pca(cluster_data: tuple) -> None:
    """Plot a PCA chart with n clusters"""
    data, kmeans = cluster_data
    n = kmeans.n_clusters
    plt.figure(figsize=(10,5))
    sns.scatterplot(x='PC_1', y='PC_2', data=data, 
                    hue='prediction', palette=sns.color_palette('hls', n), 
                    style='prediction', markers=n*['.'], s=100)

    for center, i in zip(kmeans.cluster_centers_, range(n)):
        if not i:
            plt.scatter(center[0], center[1], marker='*',s=200, c='black', label='Centroid')
        else:
            plt.scatter(center[0], center[1], marker='*',s=200, c='black')

    plt.xlabel('First Principal Component (PCA)')
    plt.ylabel('Second Principal Component (PCA)')
    plt.title('k-Means Clustering via PCA', pad=20)
    plt.legend(shadow=True);

# %%
def pipeline(df, plot=True, return_data=False):
    """Completes a full cycle of the PCA, Clustering processs for a given DataFrame."""
    cleaned = clean_raw_df(df)
    oh = one_hot(cleaned)
    centered = center(oh)
    cluster = cluster_data(centered)
    
    if plot:
        plot_scree(centered)
        plot_pca(cluster)
    
    if return_data:
        return cluster[0], cluster[1], centered

# %% [markdown]
# ## PCA --> k-Means Clustering

# %% [markdown]
# Within this section of the notebook, I will perform Principal Component Analysis (PCA) on the featured data, and then use a k-Means Clustering algorithm to identify genres in my two-dimensional track space.

# %%
data, kmeans, clustered = pipeline(df, plot=True, return_data=True)

# %%
preds = data.merge(clean_raw_df(df, pipe=False), how="inner", 
                left_on=data.index, 
                right_on=clean_raw_df(df, pipe=False).index, 
                left_index=True, 
                right_index=True)

# %%
fig = px.scatter(preds, x='PC_1', y='PC_2', hover_name='title', color="prediction")
fig.update_layout(
    height=600,
    width=900,
    title_text='PCA of Spotify Tracks'
)
fig.show()
# Out:
# <div>                            <div id="1c314ba3-946b-455d-b128-2728759f7993" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c314ba3-946b-455d-b128-2728759f7993")) {                    Plotly.newPlot(                        "1c314ba3-946b-455d-b128-2728759f7993",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>PC_1=%{x}<br>PC_2=%{y}<br>prediction=%{marker.color}<extra></extra>", "hovertext": ["Callaita", "Sacrifices (with EARTHGANG & J. Cole feat. Smino & Saba)", "Envy Me", "Me Odias?", "Quiero", "when the party's over", "Acurrucar", "Go Fuck Yourself", "Peer Gynt Suite No. 1, Op. 46: Morning Mood - Arr. for Piano", "SLOW DANCING IN THE DARK", "Hallucinate", "Break My Heart Again", "Desde el Coraz\u00f3n", "I Dreamed A Dream - From \"Les Mis\u00e9rables\"", "I DON'T CARE", "Get You (feat. Kali Uchis)", "Perfect Ten (feat. Nipsey Hussle)", "Bailar", "Worth It", "Save Me", "3 DAYS IN CHENGDU", "Jazz", "La m\u00eame", "Softly, Gently", "S'en aller", "All I Want - From \"High School Musical: The Musical: The Series\"", "HeadBand (feat. 2 Chainz) - Coucheron Remix", "Ghost Town", "Ren\u00e9", "5200", "That's Life (feat. Mac Miller & Sia)", "So Free", "Puedo Escribir los Versos Mas Tristes", "ROXANNE", "The Only Thing", "this girl", "Que Lloro (with Carla Morrison)", "Was It Something I Said", "Cherry Wine - Live", "Cucumber Water", "Someone Like You", "Violent Crimes", "All I've Ever Known", "I Only Ever Loved Your Ghost", "Moon River", "Biking", "Baller los", "Someone You Loved", "Will Hunting - Instrumental", "Go Loko", "Cursive", "Circles", "Proud Of U (feat. Young Thug)", "Piano Sonata No. 14 in C-Sharp Minor, Op. 27 No. 2 \"Moonlight\": I. Adagio sostenuto", "Wrapped Up", "Qui\u00e9n Dice", "Uno", "Chicago Freestyle (feat. Giveon)", "Motel 6", "Nothing", "Ballin' (with Roddy Ricch)", "Pork Belly", "En El Hood", "The Lark Ascending", "Lemonade - Ukulele Version", "Robbery", "Self Control", "I Might Need Security", "Waves", "Luckiest Man", "Ivy", "Cello Suite No. 1 in G Major, BWV 1007: I. Pr\u00e9lude", "STOP TRYING TO BE GOD", "Tierrita Mojada", "I Need You", "siempreestoypati", "Topanga", "SUPERPOSITION", "Reach Out", "Border On Border", "LA CANCI\u00d3N", "Under The Sun (with J. Cole & Lute feat. DaBaby)", "Dennehy", "Black Flies", "Ultralight Beam", "Pablo", "Goodbyes (Feat. Young Thug)", "From Gold", "Satori", "TOO DEEP TO TURN BACK", "Feeling Whitney", "Holocene", "Latinoam\u00e9rica (feat. Tot\u00f3 la Momposina, Susana Baca & Maria Rita)", "Solita", "Use This Gospel", "Hey, Ma", "Handel / Orch. Hale: Keyboard Suite in D Minor, HWV 437: III. Sarabande", "Dreams", "SAD!", "Skinny Love", "death bed (coffee for your head) (feat. beabadoobee)", "EARFQUAKE", "Moonlight", "YOSEMITE", "Losses", "Toosie Slide", "29 #Strafford APTS", "The London (feat. J. Cole & Travis Scott)", "La Mujer Que Bota Fuego", "Caroline", "Play (\"Shut Up!\")", "Pick Up", "Wells Fargo (with JID & EARTHGANG feat. Buddy & Guapdad 4000) - Interlude", "Querido Louis (feat. Trooko)", "Follow God", "Speaking Unto Nations (Beethoven Symphony no 7 - II )", "The Box", "Talking to the Moon", "Despacito", "Easily", "I Fall Apart", "The Well-Tempered Clavier: Book 1, BWV 846-869: 1. Prelude in C Major, BWV 846", "The Man Who Has Everything", "Where Is Love?", "From Eden", "Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)", "Re: Stacks", "Every Hour", "Nobody", "Gymnop\u00e9die No. 1", "Claire de lune", "Cayendo (Side A - Acoustic)", "666 \u0287", "Transatlanticism", "Bonfire", "Closed On Sunday", "Selah", "Marvins Room", "No Mistakes", "Rivage", "changes", "Runaway (U & I)", "Me Reh\u00faso", "watch", "Please Notice", "Get It Together", "the remedy for a broken heart (why am I so in love)", "E ...

# %% [markdown]
# ## k-Means Clustering --> PCA

# %% [markdown]
# Within this section of the notebook, I will use a k-Means Clustering algorithm to identify genres in my higher-dimensional track space, and then perform Principal Component Analysis (PCA) to reduce the featured data into a visualizable, two-dimensional space.

# %%
new_df = center(one_hot(clean_raw_df(df)))
X = design_matrix(new_df)

model = KMeans(n_clusters=NUM_CLUSTERS, init='k-means++', n_init=25)
pca = PCA(n_components=2)

predictions = model.fit_predict(X)
principal_components = pca.fit_transform(X)

target_df_pca = pd.DataFrame(data=principal_components, columns=['PC_1', 'PC_2'], index=new_df.index)
joined_df = new_df.join(target_df_pca)

joined_df['predictions'] = predictions.astype(str)
joined_df['title'] = clean_raw_df(df, pipe=False)['title']

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(x='PC_1', y='PC_2', data=joined_df, 
                hue='predictions', palette=sns.color_palette('hls', NUM_CLUSTERS), 
                style='predictions', markers=NUM_CLUSTERS*['.'], s=100)

for centroid, i in zip(model.cluster_centers_, range(NUM_CLUSTERS)):
    if not i:
        plt.scatter(centroid[0], centroid[1], marker='*',s=200, c='black', label='Centroid')
    else:
        plt.scatter(centroid[0], centroid[1], marker='*',s=200, c='black')

plt.xlabel('First Principal Component (PCA)')
plt.ylabel('Second Principal Component (PCA)')
plt.title('k-Means Clustering via PCA', pad=20)
plt.legend(shadow=True);

# %%
fig2 = px.scatter(joined_df, x='PC_1', y='PC_2', hover_name='title', color="predictions")
fig2.update_layout(
    height=900,
    width=1200,
    title_text='PCA of Spotify Tracks'
)
fig2.show()
# Out:
# <div>                            <div id="18a858b0-14cc-4d2e-8461-19d5c2cfdf38" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18a858b0-14cc-4d2e-8461-19d5c2cfdf38")) {                    Plotly.newPlot(                        "18a858b0-14cc-4d2e-8461-19d5c2cfdf38",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>predictions=6<br>PC_1=%{x}<br>PC_2=%{y}<extra></extra>", "hovertext": ["Callaita", "Sacrifices (with EARTHGANG & J. Cole feat. Smino & Saba)", "SLOW DANCING IN THE DARK", "3 DAYS IN CHENGDU", "5200", "Puedo Escribir los Versos Mas Tristes", "All I've Ever Known", "Biking", "Someone You Loved", "Go Loko", "Circles", "Proud Of U (feat. Young Thug)", "Wrapped Up", "Chicago Freestyle (feat. Giveon)", "Nothing", "Ballin' (with Roddy Ricch)", "Pork Belly", "En El Hood", "Lemonade - Ukulele Version", "Robbery", "Luckiest Man", "siempreestoypati", "Topanga", "SUPERPOSITION", "LA CANCI\u00d3N", "Under The Sun (with J. Cole & Lute feat. DaBaby)", "Pablo", "Goodbyes (Feat. Young Thug)", "Feeling Whitney", "Solita", "Hey, Ma", "Dreams", "Skinny Love", "YOSEMITE", "La Mujer Que Bota Fuego", "Pick Up", "Wells Fargo (with JID & EARTHGANG feat. Buddy & Guapdad 4000) - Interlude", "Follow God", "Despacito", "The Man Who Has Everything", "Where Is Love?", "From Eden", "Down Bad (feat. JID, Bas, J. Cole, EARTHGANG & Young Nudy)", "Every Hour", "Nobody", "changes", "Runaway (U & I)", "Me Reh\u00faso", "watch", "Please Notice", "the remedy for a broken heart (why am I so in love)", "Esc\u00e1pate Conmigo (feat. Ozuna)", "Dancing On My Own", "Thinkin Bout You", "Work Out", "Work Song", "Fuentes de Ortiz", "God Is", "Baila Baila Baila", "Freakin' Out On the Interstate", "Lo Que Siento", "Reckless", "Complicated", "God Is Fair, Sexy Nasty (feat. Kendrick Lamar)", "Fight for California", "Sunflower", "Wru - (donde est\u00e1s)", "151 Rum", "In the Summer", "Ocean Man", "Para Empezar", "January 28th", "White Ferrari", "In My Room", "Dark Fantasy", "Survival", "ARE YOU OK?", "Futura Free", "BOP", "LOVE. FEAT. ZACARI.", "When I Was Your Man", "Night Job", "Apricot Princess", "UCLA", "No More Parties In LA", "Let Her Go", "Tu No Metes Cabra", "Icon - Remix", "Faucets (feat. Healy)", "Leave Me Alone", "Second Time", "Yo Voy (feat. Daddy Yankee)", "Jar of Hearts", "YEAH RIGHT", "Loving Is Easy", "One More Time", "Bound 2", "33 \u201cGOD\u201d", "B", "Good Guy", "Stay", "Recu\u00e9rdame (Reencuentro)", "Already Gone", "Don't Think Twice, It's All Right", "Somebody Else", "Dead Or Alive", "Water", "Ni**as In Paris", "Quiero Volverte a Ver", "Lost in the Sauce", "Sk8board P", "I Thought About Killing You", "In My Feelings", "Look At Me!", "Lemon Tree", "God's Plan", "I Know Places", "Un Poco Loco", "transiciones", "Felices los 4", "Homesick Remedy", "Blueberry Faygo", "Sensualidad", "Passionfruit", "Expl\u00edcale (feat. Bad Bunny)", "Someone New", "Wouldn't Leave", "If the World Was Ending - feat. Julia Michaels", "Die For Me (feat. Future & Halsey)", "going down!", "Self Care", "Pink Champagne", "DNA.", "Power Trip (feat. Miguel)", "Saint-Tropez", "bad guy", "Se Prepar\u00f3", "Photograph", "All I Want for Christmas Is You", "Foreplay", "Rise Up", "Buried Alive Interlude", "White Iverson", "Alright", "Let It Snow! Let It Snow! Let It Snow!", "Ophelia", "F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar)", "Story of My Life", "Landed", "Si Veo a Tu Mam\u00e1", "Television / So Far So Good", "Pound Cake / Paris Morton Music 2", "Pretty Sweet", "ROCKSTAR (feat. Roddy Ricch)", "ENTROPY", "03' Adolescence", "Elevate", "Bleeding Love", "The Show Goes On", "Emotionless", "Bitch, Don\u2019t Kill My Vibe", "Pero Ya No", "Mine", "Hablemos", "Let It Go", "a lot", "FML", "Go Flex", "When To Say W ...
